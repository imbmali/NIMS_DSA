# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 10
b = 3

addition = a + b
subtraction = a - b
multiplication = a * b
division = a / b
floor_division = a // b
modulus = a % b
exponentiation = a ** b

print("Addition:", addition)
print("Subtraction:", subtraction)
print("Multiplication:", multiplication)
print("Division:", division)
print("Floor Division:", floor_division)
print("Modulus:", modulus)
print("Exponentiation:", exponentiation)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor Division: 3
# Modulus: 1
# Exponentiation: 1000

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Comparison Operators in Python
# Define two variables
x = 5
y = 7
# Equal to (==) operator
print(f"x == y : {x == y}")  

# Not Equal to (!=) operator
print(f"x != y : {x != y}") 

# Greater than (>) operator
print(f"x > y : {x > y}")   

# Less than (<) operator
print(f"x < y : {x < y}")    

# Greater than or equal to (>=) operator
print(f"x >= y : {x >= y}")  

# Less than or equal to (<=) operator
print(f"x <= y : {x <= y}")
# Out:
# x == y : False
# x != y : True
# x > y : False
# x < y : True
# x >= y : False
# x <= y : True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = True
b = False
logical_and = a and b    
logical_or = a or b     
logical_not_a = not a   
logical_not_b = not b    
print(f'a and b : {logical_and}')
print(f'a or b  : {logical_or}')
print(f'not a    : {logical_not_a}')
print(f'not b    : {logical_not_b}')
# Out:
# a and b : False
# a or b  : True
# not a    : False
# not b    : True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 5   
y = 3   
bitwise_and = x & y     
bitwise_or = x | y      
bitwise_xor = x ^ y     
bitwise_not_x = ~x      
left_shift = x << 1     
right_shift = x >> 1   

print(f'Bitwise AND (x & y): {bitwise_and}')
print(f'Bitwise OR (x | y): {bitwise_or}')
print(f'Bitwise XOR (x ^ y): {bitwise_xor}')
print(f'Bitwise NOT (~x): {bitwise_not_x}')
print(f'Left Shift (x << 1): {left_shift}')
print(f'Right Shift (x >> 1): {right_shift}')
# Out:
# Bitwise AND (x & y): 1
# Bitwise OR (x | y): 7
# Bitwise XOR (x ^ y): 6
# Bitwise NOT (~x): -6
# Left Shift (x << 1): 10
# Right Shift (x >> 1): 2
